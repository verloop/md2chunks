# %% [markdown]
# ## Visualise each chunk and its size

# %% [markdown]
# ### 1. We create nodes as usual first

# %%
from src.file_reader import FileReader, process_md, LOGGER
from src.settings import MD_DIR_PATH, PROCESSED_DIR_PATH, CHUNK_SIZE
from pathlib import Path


md_paths = list(Path(MD_DIR_PATH).iterdir())
if md_paths:
    try:
        for filepath in md_paths:
            file_suffix = filepath.suffix
            # Only process for markdown files in the directory
            if file_suffix != ".md":
                continue
            LOGGER.info(filepath)
            with open(filepath, encoding="utf-8") as f:
                md = f.read()
            processed_md = process_md(md)
            filename = filepath.name
            LOGGER.info(filename)
            processed_md_path = str(Path(PROCESSED_DIR_PATH).joinpath(filename))
            with open(processed_md_path, "w", encoding="UTF-8") as f:
                f.write(processed_md)

    except Exception:
        LOGGER.exception("Markdown document parsing failed")
        raise

    LOGGER.info("Parsing and saving MD files completed succesfully")
else:
    LOGGER.info("No MD files found")

nodes = FileReader(input_dir=PROCESSED_DIR_PATH).load_data()
# Out:
# 2025-02-21 11:32:54 - src - INFO - /Users/rajeevwarrier/Documents/md_folder/toyota.md
# 2025-02-21 11:32:54 - src - INFO - toyota.md
# 2025-02-21 11:32:54 - src - INFO - Parsing and saving MD files completed succesfully

# %% [markdown]
# ### 2. Print chunk, metadata, length of tokens and check if chunk is within size

# %%
import tiktoken

tokenizer = tiktoken.encoding_for_model("gpt-3.5-turbo")
prev_metadata = ""
start = True
for node in nodes:
    inside_limit = False
    metadata_str: str = "\n".join(
        [f"{key}: {value}" for key, value in node.metadata.items()]
    )
    token_length = len(tokenizer.encode(node.text))
    if token_length < ((CHUNK_SIZE - len(tokenizer.encode(metadata_str))) * 1.4):
        inside_limit = True

    if prev_metadata == node.metadata or start:
        print(node.metadata)
        print(f"Length of tokens: {token_length}")
        print(f"Is chunk inside token limit?: {inside_limit}")
        print(node.text)
        print(100 * "-")
    else:
        print(100 * "=")
        print(100 * "=")
        print(node.metadata)
        print(f"Length of tokens: {token_length}")
        print(f"Is chunk inside token limit?: {inside_limit}")
        print(node.text)
        print(100 * "-")
    start = False
    prev_metadata = node.metadata
# Out:
# {'doc_name': 'README', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 20
# Is chunk inside token limit?: True
#
# # README
# # md2chunks
#
# Context Enriched Markdown Chunking for RAG
#
#
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 260
# Is chunk inside token limit?: True
# # toyota
# # Model Name: Camry 2025
#
# Tagline for Camry 2025: Greater Handling & Styling. Category for Camry 2025: Hybrid. Test Drive Availability for Camry 2025: Not Available. Vehicle Link for Camry 2025: /vehicles/camry
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Technical Specifications of Model Trims
# ### 2.5L 4 Cylinder Hybrid Limited:
# #### Dimensions & Weight
#
# * Overall length (mm): 4920
# * Overall width (mm): 1840
# * Overall height (mm): 1445
# * Wheelbase (mm): 2825
# * Tread Front (mm): 1600
# * Tread Rear (mm): 1600
# * Ground clearance (mm): 145
# * Curb weight (kg): 1640 - 1660
# * Gross vehicle weight (kg): 2100
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Technical Specifications of Model Trims
# ### 2.5L 4 Cylinder Hybrid Limited:
# #### Chassis
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 235
# Is chunk inside token limit?: True
# # toyota
# # Model Name: Camry 2025
#
# * Brakes Front: Ventilated discs
# * Brakes Rear: Solid Discs
# * Minimum turning radius (curb to curb) (m): 5.7
# * Fuel tank capacity (litres): 50
# * Tyres: 235/45R18
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Technical Specifications of Model Trims
# ### 2.5L 4 Cylinder Hybrid Limited:
# #### Engines
#
# * Piston Displacement (cc): 2487
# * Max. output (EEC) net (kW/rpm): 225 / 6000
# * Max. torque (EEC) (Nm/rpm): 221 / 3600 - 5200
# * Fuel system: Direct Multipoint Injection
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Technical Specifications of Model Trims
# ### 2.5L 4 Cylinder Hybrid GLE:
# #### Dimensions & Weight
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 265
# Is chunk inside token limit?: True
# # toyota
# # Model Name: Camry 2025
#
# * Overall length (mm): 4920
# * Overall width (mm): 1840
# * Overall height (mm): 1445
# * Wheelbase (mm): 2825
# * Tread Front (mm): 1600
# * Tread Rear (mm): 1600
# * Ground clearance (mm): 145
# * Curb weight (kg): 1640 - 1660
# * Gross vehicle weight (kg): 2100
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Technical Specifications of Model Trims
# ### 2.5L 4 Cylinder Hybrid GLE:
# #### Chassis
#
# * Brakes Front: Ventilated discs
# * Brakes Rear: Solid Discs
# * Minimum turning radius (curb to curb) (m): 5.7
# * Fuel tank capacity (litres): 50
# * Tyres: 235/45R18
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Technical Specifications of Model Trims
# ### 2.5L 4 Cylinder Hybrid GLE:
# #### Engines
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 261
# Is chunk inside token limit?: True
# # toyota
# # Model Name: Camry 2025
#
# * Piston Displacement (cc): 2487
# * Max. output (EEC) net (kW/rpm): 225 / 6000
# * Max. torque (EEC) (Nm/rpm): 221 / 3600 - 5200
# * Fuel system: Direct Multipoint Injection
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Technical Specifications of Model Trims
# ### 2.5L 4 Cylinder Hybrid LE:
# #### Dimensions & Weight
#
# * Overall length (mm): 4920
# * Overall width (mm): 1840
# * Overall height (mm): 1445
# * Wheelbase (mm): 2825
# * Tread Front (mm): 1610
# * Tread Rear (mm): 1610
# * Ground clearance(mm): 145
# * Curb weight (kg): 1595 - 1625
# * Gross vehicle weight (kg): 2100
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Technical Specifications of Model Trims
# ### Chassis
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 213
# Is chunk inside token limit?: True
# # toyota
# # Model Name: Camry 2025
#
# * Brakes Front: Ventilated discs
# * Brakes Rear: Solid Discs
# * Minimum turning radius (curb to curb) (m): 5.7
# * Fuel tank capacity (litres): 50
# * Tyres: 215/55R17
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Technical Specifications of Model Trims
# ### Engines
#
# * Piston Displacement (cc): 2487
# * Max. output (EEC net) Hp/rpm: 225 / 6000
# * Max. torque (EEC net) Nm/rpm: 221 / 3600 - 5200
# * Fuel system: Direct Multipoint Injection
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Hybrid E:
# ### Dimensions & Weight
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 246
# Is chunk inside token limit?: True
# # toyota
# # Model Name: Camry 2025
#
# * Overall length (mm): 4920
# * Overall width (mm): 1845
# * Overall height (mm): 1445
# * Wheelbase (mm): 2825
# * Tread Front (mm): 1600
# * Tread Rear (mm): 1625
# * Ground clearance(mm): 145
# * Curb weight (kg): 1595 - 1625
# * Gross vehicle weight (kg): 2100
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Hybrid E:
# ### Chassis
#
# * Brakes Front: Ventilated discs
# * Brakes Rear: Solid Discs
# * Minimum turning radius (curb to curb) (m): 5.7
# * Fuel tank capacity (litres): 50
# * Tyres: 215/55R17
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Hybrid E:
# ### Engines
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 256
# Is chunk inside token limit?: True
# # toyota
# # Model Name: Camry 2025
#
# * Piston Displacement (cc): 2487
# * Max. output (EEC net) Hp/rpm: 225 / 6000
# * Max. torque (EEC net) Nm/rpm: 221 / 3600 - 5200
# * Fuel system: Direct Multipoint Injection
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Hybrid E+
# ### Dimensions & Weight
#
# * Overall length (mm): 4920
# * Overall width (mm): 1845
# * Overall height (mm): 1445
# * Wheelbase (mm): 2825
# * Tread Front (mm): 1600
# * Tread Rear (mm): 1625
# * Ground clearance(mm): 145
# * Curb weight (kg): 1560 - 1560
# * Gross vehicle weight (kg): 2100
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Hybrid E+
# ### Chassis
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 218
# Is chunk inside token limit?: True
# # toyota
# # Model Name: Camry 2025
#
# * Brakes Front: Ventilated discs
# * Brakes Rear: Solid Discs
# * Minimum turning radius (curb to curb) (m): 5.7
# * Fuel tank capacity (litres): 50
# * Tyres: 205/65R16
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Hybrid E+
# ### Engines
#
# * Piston Displacement (cc): 2487
# * Max. output (EEC net) Hp/rpm: 225 / 6000
# * Max. torque (EEC net) Nm/rpm: 221 / 3600 - 5200
# * Fuel system: Direct Multipoint Injection
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine GLE:
# ## Dimensions & Weight
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 272
# Is chunk inside token limit?: True
# # toyota
# # Model Name: Camry 2025
#
# * Overall length (mm): 4920
# * Overall width (mm): 1840
# * Overall height (mm): 1445
# * Wheelbase (mm): 2825
# * Tread Front/Rear (mm): 1600
# * Ground clearance(mm): 145
# * Curb weight (kg): 1560
# * Gross vehicle weight (kg): 2030
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Chassis
#
# * Brakes Front: Ventilated discs
# * Brakes Rear: Solid Discs
# * Minimum turning radius (curb to curb) (m): 5.7
# * Fuel tank capacity (litres): 60
# * Tyres: 235/45R18
#
# # toyota
# # Model Name: Camry 2025
#
# # Model Name: Camry 2025
# ## Engines
#
# * Piston Displacement (cc): 2487
# * Max. output (EEC net) hp/rpm: 207 / 6600
# * Max. torque (EEC net) Kgfm/rpm 240/4000-5000
# * Fuel system: Direct Multipoint Injection
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 283
# Is chunk inside token limit?: True
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine LE
# ### Dimensions & Weight
#
# * Overall length (mm): 4920
# * Overall width (mm): 1840
# * Overall height (mm): 1445
# * Wheelbase (mm): 2825
# * Tread Front/Rear (mm): 1600
# * Ground clearance(mm): 145
# * Curb weight (kg): 1540
# * Gross vehicle weight (kg): 2030
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine LE
# ### Chassis
#
# * Brakes Front: Ventilated discs
# * Brakes Rear: Discs
# * Minimum turning radius (curb to curb) (m): 5.7
# * Fuel tank capacity (litres): 60
# * Tyres: 215 - 55 R17
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine LE
# ### Engines
#
# * Piston Displacement (cc): 2487
# * Max. output (EEC net) hp/rpm: 207 / 6600
# * Max. torque (EEC net) Kgfm/rpm 240/4000-5000
# * Fuel system: Direct Multipoint Injection
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 274
# Is chunk inside token limit?: True
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# * Overall length (mm): 4885
# * Overall width (mm): 1840
# * Overall height (mm): 1445
# * Wheelbase (mm): 2825
# * Tread Front/Rear (mm): 1600
# * Ground clearance(mm): 145
# * Curb weight (kg): 1555
# * Gross vehicle weight (kg): 2030
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Chassis
#
# * Brakes Front: Ventilated discs
# * Brakes Rear: Discs
# * Minimum turning radius (curb to curb) (m): 5.8
# * Fuel tank capacity (litres): 60
# * Tyres: 205 - 65 R16
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Engines
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 226
# Is chunk inside token limit?: True
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# * Piston Displacement (cc): 2487
# * Max. output (EEC net) (kW/rpm): 201 / 6600
# * Max. torque (EEC net) (Kgm/rpm): 24.0/4400 - 5000
# * Fuel system: Direct Multipoint Injection
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Available Colors for Camry 2025:
#
# * Precious Metal (Image: [alt text](https://files.toyota.com.br/kfs-public/2024-07/Preciou%20Metal.png?VersionId=vGLQ2NfhGsCo3e7z4ycAEyez_IsFp5rP&_=1&tei=))
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 311
# Is chunk inside token limit?: True
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# * Dark Blue Mica (Image: [alt text](https://files.toyota.com.br/kfs-public/2024-07/Darkblue%20Mica.png?VersionId=MjcwoFMVNSsvZ5z5P5CAU6PzA2s4Pv6yJ&_=1&tei=))
# * Attitude Black (Image: [alt text](https://files.toyota.com.br/kfs-public/2024-07/Attitude%20Black.png?VersionId=6uVZ5ka6CCBlugeQ0xyMG4RgpyRtKd_9&_=1&tei=))
# * Silver Metallic (Image: [alt text](https://files.toyota.com.br/kfs-public/2024-07/Silver%20Metallic.png?VersionId=0HBLeq3RzSob0HOff6RXyhyzP3XyAunv&_=1&tei=))
# * Oxide Bronze (Image: [alt text](https://files.toyota.com.br/kfs-public/2024-07/Preciou%20Metal.png?VersionId=sL_gSpyuFfaWlvqLj_79kFhlMaQy3tQ8&_=1&tei=))
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 276
# Is chunk inside token limit?: True
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Available Trims for Camry 2025:
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# * Camry 2.5 E, Gasoline Engine, 201 Horsepower, 8-Speed Automatic Transmission, 16" Steel Wheels/8" Multi Information Display/7â€ TFT Display/Rear Seats
# * Camry 2.5 G, Gasoline Engine, 201 Horsepower, 8-Speed Automatic Transmission, 17â€ Tone Aluminum Wheels, 12.3â€ Multi Information Display/7â€ TFT Display/Rear Seats
# * Camry 2.5 V, Gasoline Engine, 201 Horsepower, 8-Speed Automatic Transmission, 18â€ Tone Aluminum Wheels, 12.3â€ Multi Information Display/7â€ TFT Display/Rear Seats
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 151
# Is chunk inside token limit?: True
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Brochures for Camry 2025:
#
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# * Camry 2025 (PDF: [here](https://files.toyota.com.br/kfs-public/2024-08/camry.pdf?VersionId=LimZnEe8NWsZbazew_pmVNd9FjtzpZe6))
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 283
# Is chunk inside token limit?: True
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Key Features of Camry 2025:
#
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# * **Performance:** The All-New Camry excels in providing smooth acceleration and a comfortable ride that you can look forward to each day. With two powertrains at its disposal, it is all designed to better power and efficiency.
# * **Design:** The All-New Camryâ€™s exterior and interior design promise a clean, enduring, powerful driving experience. Its exterior and interior design shows elegance every angle, executed without compromise.
# * **Comfort:** Comfort comes standard in the All-New Camry, providing you with quality features and easy usability. Spend countless hours inside your Camry without any discomfort.
# * **Safety:** The All-New Camry comes equipped with Toyota Safety Sense to ensure your safety in all kinds of situations. These include Pre-Collision System (PCS), Emergency Steering Assist (ESA), Automatic High Beam (AHB), Panoramic View Monitor and more. Up to 6 SRS airbags are available on the Camry.
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 167
# Is chunk inside token limit?: True
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Comfort Details of Camry 2025:
#
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# * **Multimedia System:** The centerpiece of the instrument panel features a full-HD widescreen display with high visibility and diverse functionality that is easy to use.
# * **Voice Command:** Intuitive command ensures optimal usability while inside the car.
# * **Enjoy clearer, more powerful audio:** The JBL by Harman/Clari-fi technology provides rich clarity with every note.
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 247
# Is chunk inside token limit?: True
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Safety Details of Camry 2025:
#
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# * **Dynamic Radar Cruise Control (DRCC):** Millimeter-wave radar and a monocular camera are used to detect the vehicle in front, allowing the car to follow them and help maintain a safe distance.
# * **Pre-Collision System (PCS):** A logical addition to the All-New Camryâ€™s Toyota Safety Sense system.
# * **Blind Spot Monitor (BSM):** Provides the driver with a helpful cue by detecting vehicles in multiple road lanes and indicates their presence.
# * **Electronic Rear View Mirror:** A wider field of view with lesser obstruction is provided with the electronic rearview mirror.
# * **Head-Up Display (HUD):** Information such as the speed of the driving is projected onto the windshield within the driverâ€™s field of view.
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 341
# Is chunk inside token limit?: False
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Design Details of Camry 2025:
#
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# * **Exterior Design:** The Camryâ€™s exterior design aims to provide a sense of command combined with sophistication that indicates a clean and refreshing image of Toyotaâ€™s premium sedans across the board.
# * **Interior Design:** A sleek design is coupled with innovative technology to keep you connected and entertained.
# * **Tires and Wheels:** Dealerships can help with car accessories especially when it comes to the wheel designs. 16â€ Wheel Cap, 17â€ Aluminum Wheel and 18â€ Aluminum Wheel.
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Performance Details of Camry 2025:
#
# # Model Name: Camry 2025
# ## 2.5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# * **New Engines:** The Camry engine lineup includes two powertrains in its quest for even greater power and fuel efficiency. All figures mentioned are in accordance with the above details.
#   Certainly! Here is the content extracted and formatted in Markdown:
# ----------------------------------------------------------------------------------------------------
# {'doc_name': 'toyota', 'doc_type': '.md', 'chunk_size': 256, 'chunk_overlap': 1.4}
# Length of tokens: 220
# Is chunk inside token limit?: True
# # Model Name: Camry 2025
# ## 2#-#5L 4 Cylinder Engine E
# ### Dimensions & Weight
#
# `- 2.5L Gasoline Engine: Equipped with a 2.5L inline four-cylinder engine that is better for the environment without giving up its excellent fuel economy, high output, and high responsiveness.
#
# * 8-Speed Automatic Transmission: Tight gear ratio and component optimization provides excellent gearshift response and a smoother acceleration feel that matches the driver's intent. It also improves fuel economy and quietness.
# * 2.5L Hybrid System: The hybrid system delivers smooth, powerful acceleration with great accelerator responsiveness through optimal control of both the combustion engine and the electric motor. Experience the exceptional fuel economy and smooth driving feel that only a hybrid system can offer.
# * CVT (Tokyo Power Split Transaxle): The Camry features a compact, lightweight transaxle. With improved efficiency of power transmission from the combustion engine and electric motor to the wheels, it drives even more quietly while offering excellent power performance and fuel economy.`
# ----------------------------------------------------------------------------------------------------
